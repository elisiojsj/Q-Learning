# %%
import gym
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F

import time
import matplotlib.pyplot as plt

# %%
class qAgent:
    def __init__(self, n_action_space, n_observation_space, epsilon, alpha, discount_factor ):
        self.n_action_space = n_action_space
        self.n_observation_space = n_observation_space
        
        self.epsilon = epsilon
        self.alpha = alpha
        self.discount_factor = discount_factor
        
        self.q_table = np.zeros([n_observation_space, n_action_space])
        
    def get_q_value(self, state, action):
        return self.q_table[state][action]
    
    def set_q_value(self, state, action, value):
        self.q_table[state][action] = value
        
    def get_action_epsilon_greedy(self, state):    
        if np.random.rand() < self.epsilon:
            action = np.random.choice(self.n_action_space)
        else:
            action = self.get_best_action(state) # greedy policy 
        return action
    
    def get_best_action(self, state):
        best_action = [self.get_q_value(state,action) for action in range(self.n_action_space)]
        best_action = np.argmax(best_action)
        return best_action 
    
    def update_q_table(self, state, new_state, action, reward):
        # Q(S,A) = Q(S,A) + alpha[R + gamma*maxaQ(S',a)-Q(S,A)]
        
        value_new_state = self.get_q_value(new_state, self.get_best_action(new_state))
        
        new_q_value = self.get_q_value(state,action) +\
                self.alpha*(reward+self.discount_factor*value_new_state-self.get_q_value(state,action))
        
        #new_q_value = (1 - self.alpha)*self.get_q_value(state,action)+self.alpha*(reward+self.discount_factor*value_new_state)
        
        self.set_q_value(state, action, new_q_value)

# %%
# Load Taxi-v3 environment 
# https://gym.openai.com/envs/Taxi-v3/
env = gym.make('Taxi-v3')

# %%
"""
For this environment we have 6 actions and 500 discrete states.
https://github.com/openai/gym/blob/master/gym/envs/toy_text/taxi.py

Actions:
There are 6 discrete deterministic actions:
- 0: move south
- 1: move north
- 2: move east 
- 3: move west 
- 4: pickup passenger
- 5: dropoff passenger

Observations: 
    There are 500 discrete states since there are 25 taxi positions, 5 possible locations of the passenger 
    (including the case when the passenger is in the taxi), and 4 destination locations. 
"""

print("Number of possible actions:", env.action_space.n)
print("Number of possible states:", env.observation_space.n)
# Out:
# Number of possible actions: 6
# Number of possible states: 500

# %%
# Hyperparameters
epsilon = 1
alpha = 0.5
discount_factor = 0.99

agent = qAgent(n_action_space=env.action_space.n,
               n_observation_space=env.observation_space.n,
               epsilon=epsilon,
               alpha=alpha,
               discount_factor=discount_factor)

# %%
def train(env, agent, n_episodes=20):
    rewards = []
    
    for ep in range(n_episodes):
        n_iter = 0
        state = env.reset()
        done = False
        ep_rewards = 0.0
        
        while not done:
            n_iter += 1
            action = agent.get_action_epsilon_greedy(state)
            
            new_state, reward, done, info = env.step(action)
            
            agent.update_q_table(state, new_state, action, reward)
            
            state = new_state
            ep_rewards += reward
            
        print("Ep {}\t done after {} iteractions\t epsilon={:.2f}".format(ep+1, n_iter, agent.epsilon))    
        agent.epsilon *= 0.95
        rewards.append(ep_rewards)
    env.close()
    return rewards

# %%
rewards = train(env, agent, n_episodes=1000)
# Out:
# Ep 1	 done after 148 iteractions	 epsilon=1.00
# Ep 2	 done after 200 iteractions	 epsilon=0.95
# Ep 3	 done after 200 iteractions	 epsilon=0.90
# Ep 4	 done after 200 iteractions	 epsilon=0.86
# Ep 5	 done after 200 iteractions	 epsilon=0.81
# Ep 6	 done after 200 iteractions	 epsilon=0.77
# Ep 7	 done after 200 iteractions	 epsilon=0.74
# Ep 8	 done after 200 iteractions	 epsilon=0.70
# Ep 9	 done after 200 iteractions	 epsilon=0.66
# Ep 10	 done after 200 iteractions	 epsilon=0.63
# Ep 11	 done after 200 iteractions	 epsilon=0.60
# Ep 12	 done after 200 iteractions	 epsilon=0.57
# Ep 13	 done after 200 iteractions	 epsilon=0.54
# Ep 14	 done after 200 iteractions	 epsilon=0.51
# Ep 15	 done after 200 iteractions	 epsilon=0.49
# Ep 16	 done after 200 iteractions	 epsilon=0.46
# Ep 17	 done after 200 iteractions	 epsilon=0.44
# Ep 18	 done after 200 iteractions	 epsilon=0.42
# Ep 19	 done after 200 iteractions	 epsilon=0.40
# Ep 20	 done after 200 iteractions	 epsilon=0.38
# Ep 21	 done after 200 iteractions	 epsilon=0.36
# Ep 22	 done after 200 iteractions	 epsilon=0.34
# Ep 23	 done after 200 iteractions	 epsilon=0.32
# Ep 24	 done after 199 iteractions	 epsilon=0.31
# Ep 25	 done after 200 iteractions	 epsilon=0.29
# Ep 26	 done after 200 iteractions	 epsilon=0.28
# Ep 27	 done after 167 iteractions	 epsilon=0.26
# Ep 28	 done after 145 iteractions	 epsilon=0.25
# Ep 29	 done after 200 iteractions	 epsilon=0.24
# Ep 30	 done after 200 iteractions	 epsilon=0.23
# Ep 31	 done after 200 iteractions	 epsilon=0.21
# Ep 32	 done after 160 iteractions	 epsilon=0.20
# Ep 33	 done after 200 iteractions	 epsilon=0.19
# Ep 34	 done after 200 iteractions	 epsilon=0.18
# Ep 35	 done after 200 iteractions	 epsilon=0.17
# Ep 36	 done after 22 iteractions	 epsilon=0.17
# Ep 37	 done after 123 iteractions	 epsilon=0.16
# Ep 38	 done after 200 iteractions	 epsilon=0.15
# Ep 39	 done after 200 iteractions	 epsilon=0.14
# Ep 40	 done after 161 iteractions	 epsilon=0.14
# Ep 41	 done after 200 iteractions	 epsilon=0.13
# Ep 42	 done after 175 iteractions	 epsilon=0.12
# Ep 43	 done after 200 iteractions	 epsilon=0.12
# Ep 44	 done after 185 iteractions	 epsilon=0.11
# Ep 45	 done after 200 iteractions	 epsilon=0.10
# Ep 46	 done after 200 iteractions	 epsilon=0.10
# Ep 47	 done after 200 iteractions	 epsilon=0.09
# Ep 48	 done after 200 iteractions	 epsilon=0.09
# Ep 49	 done after 200 iteractions	 epsilon=0.09
# Ep 50	 done after 113 iteractions	 epsilon=0.08
# Ep 51	 done after 200 iteractions	 epsilon=0.08
# Ep 52	 done after 131 iteractions	 epsilon=0.07
# Ep 53	 done after 197 iteractions	 epsilon=0.07
# Ep 54	 done after 200 iteractions	 epsilon=0.07
# Ep 55	 done after 200 iteractions	 epsilon=0.06
# Ep 56	 done after 132 iteractions	 epsilon=0.06
# Ep 57	 done after 200 iteractions	 epsilon=0.06
# Ep 58	 done after 90 iteractions	 epsilon=0.05
# Ep 59	 done after 200 iteractions	 epsilon=0.05
# Ep 60	 done after 200 iteractions	 epsilon=0.05
# Ep 61	 done after 200 iteractions	 epsilon=0.05
# Ep 62	 done after 17 iteractions	 epsilon=0.04
# Ep 63	 done after 151 iteractions	 epsilon=0.04
# Ep 64	 done after 150 iteractions	 epsilon=0.04
# Ep 65	 done after 44 iteractions	 epsilon=0.04
# Ep 66	 done after 187 iteractions	 epsilon=0.04
# Ep 67	 done after 137 iteractions	 epsilon=0.03
# Ep 68	 done after 87 iteractions	 epsilon=0.03
# Ep 69	 done after 48 iteractions	 epsilon=0.03
# Ep 70	 done after 100 iteractions	 epsilon=0.03
# Ep 71	 done after 122 iteractions	 epsilon=0.03
# Ep 72	 done after 200 iteractions	 epsilon=0.03
# Ep 73	 done after 193 iteractions	 epsilon=0.02
# Ep 74	 done after 200 iteractions	 epsilon=0.02
# Ep 75	 done after 135 iteractions	 epsilon=0.02
# Ep 76	 done after 96 iteractions	 epsilon=0.02
# Ep 77	 done after 173 iteractions	 epsilon=0.02
# Ep 78	 done after 146 iteractions	 epsilon=0.02
# Ep 79	 done after 120 iteractions	 epsilon=0.02
# Ep 80	 done after 91 iteractions	 epsilon=0.02
# Ep 81	 done after 139 iteractions	 epsilon=0.02
# Ep 82	 done after 200 iteractions	 epsilon=0.02
# Ep 83	 done after 144 iteractions	 epsilon=0.01
# Ep 84	 done after 200 iteractions	 epsilon=0.01
# Ep 85	 done after 109 iteractions	 epsilon=0.01
# Ep 86	 done after 93 iteractions	 epsilon=0.01
# Ep 87	 done after 98 iteractions	 epsilon=0.01
# Ep 88	 done after 140 iteractions	 epsilon=0.01
# Ep 89	 done after 200 iteractions	 epsilon=0.01
# Ep 90	 done after 73 iteractions	 epsilon=0.01
# Ep 91	 done after 15 iteractions	 epsilon=0.01
# Ep 92	 done after 200 iteractions	 epsilon=0.01
# Ep 93	 done after 128 iteractions	 epsilon=0.01
# Ep 94	 done after 136 iteractions	 epsilon=0.01
# Ep 95	 done after 11 iteractions	 epsilon=0.01
# Ep 96	 done after 147 iteractions	 epsilon=0.01
# Ep 97	 done after 155 iteractions	 epsilon=0.01
# Ep 98	 done after 96 iteractions	 epsilon=0.01
# Ep 99	 done after 75 iteractions	 epsilon=0.01
# Ep 100	 done after 168 iteractions	 epsilon=0.01
# Ep 101	 done after 70 iteractions	 epsilon=0.01
# Ep 102	 done after 118 iteractions	 epsilon=0.01
# Ep 103	 done after 163 iteractions	 epsilon=0.01
# Ep 104	 done after 185 iteractions	 epsilon=0.01
# Ep 105	 done after 58 iteractions	 epsilon=0.00
# Ep 106	 done after 32 iteractions	 epsilon=0.00
# Ep 107	 done after 106 iteractions	 epsilon=0.00
# Ep 108	 done after 139 iteractions	 epsilon=0.00
# Ep 109	 done after 165 iteractions	 epsilon=0.00
# Ep 110	 done after 70 iteractions	 epsilon=0.00
# Ep 111	 done after 107 iteractions	 epsilon=0.00
# Ep 112	 done after 28 iteractions	 epsilon=0.00
# Ep 113	 done after 100 iteractions	 epsilon=0.00
# Ep 114	 done after 11 iteractions	 epsilon=0.00
# Ep 115	 done after 78 iteractions	 epsilon=0.00
# Ep 116	 done after 99 iteractions	 epsilon=0.00
# Ep 117	 done after 134 iteractions	 epsilon=0.00
# Ep 118	 done after 38 iteractions	 epsilon=0.00
# Ep 119	 done after 114 iteractions	 epsilon=0.00
# Ep 120	 done after 73 iteractions	 epsilon=0.00
# Ep 121	 done after 34 iteractions	 epsilon=0.00
# Ep 122	 done after 108 iteractions	 epsilon=0.00
# Ep 123	 done after 200 iteractions	 epsilon=0.00
# Ep 124	 done after 28 iteractions	 epsilon=0.00
# Ep 125	 done after 158 iteractions	 epsilon=0.00
# Ep 126	 done after 125 iteractions	 epsilon=0.00
# Ep 127	 done after 104 iteractions	 epsilon=0.00
# Ep 128	 done after 148 iteractions	 epsilon=0.00
# Ep 129	 done after 54 iteractions	 epsilon=0.00
# Ep 130	 done after 22 iteractions	 epsilon=0.00
# Ep 131	 done after 26 iteractions	 epsilon=0.00
# Ep 132	 done after 69 iteractions	 epsilon=0.00
# Ep 133	 done after 84 iteractions	 epsilon=0.00
# Ep 134	 done after 66 iteractions	 epsilon=0.00
# Ep 135	 done after 129 iteractions	 epsilon=0.00
# Ep 136	 done after 12 iteractions	 epsilon=0.00
# Ep 137	 done after 52 iteractions	 epsilon=0.00
# Ep 138	 done after 79 iteractions	 epsilon=0.00
# Ep 139	 done after 51 iteractions	 epsilon=0.00
# Ep 140	 done after 83 iteractions	 epsilon=0.00
# Ep 141	 done after 105 iteractions	 epsilon=0.00
# Ep 142	 done after 181 iteractions	 epsilon=0.00
# Ep 143	 done after 62 iteractions	 epsilon=0.00
# Ep 144	 done after 10 iteractions	 epsilon=0.00
# Ep 145	 done after 16 iteractions	 epsilon=0.00
# Ep 146	 done after 28 iteractions	 epsilon=0.00
# Ep 147	 done after 26 iteractions	 epsilon=0.00
# Ep 148	 done after 36 iteractions	 epsilon=0.00
# Ep 149	 done after 72 iteractions	 epsilon=0.00
# Ep 150	 done after 112 iteractions	 epsilon=0.00
# Ep 151	 done after 89 iteractions	 epsilon=0.00
# Ep 152	 done after 26 iteractions	 epsilon=0.00
# Ep 153	 done after 78 iteractions	 epsilon=0.00
# Ep 154	 done after 39 iteractions	 epsilon=0.00
# Ep 155	 done after 60 iteractions	 epsilon=0.00
# Ep 156	 done after 50 iteractions	 epsilon=0.00
# Ep 157	 done after 77 iteractions	 epsilon=0.00
# Ep 158	 done after 58 iteractions	 epsilon=0.00
# Ep 159	 done after 10 iteractions	 epsilon=0.00
# Ep 160	 done after 112 iteractions	 epsilon=0.00
# Ep 161	 done after 20 iteractions	 epsilon=0.00
# Ep 162	 done after 60 iteractions	 epsilon=0.00
# Ep 163	 done after 9 iteractions	 epsilon=0.00
# Ep 164	 done after 24 iteractions	 epsilon=0.00
# Ep 165	 done after 41 iteractions	 epsilon=0.00
# Ep 166	 done after 37 iteractions	 epsilon=0.00
# Ep 167	 done after 26 iteractions	 epsilon=0.00
# Ep 168	 done after 11 iteractions	 epsilon=0.00
# Ep 169	 done after 56 iteractions	 epsilon=0.00
# Ep 170	 done after 23 iteractions	 epsilon=0.00
# Ep 171	 done after 56 iteractions	 epsilon=0.00
# Ep 172	 done after 46 iteractions	 epsilon=0.00
# Ep 173	 done after 59 iteractions	 epsilon=0.00
# Ep 174	 done after 10 iteractions	 epsilon=0.00
# Ep 175	 done after 44 iteractions	 epsilon=0.00
# Ep 176	 done after 84 iteractions	 epsilon=0.00
# Ep 177	 done after 38 iteractions	 epsilon=0.00
# Ep 178	 done after 12 iteractions	 epsilon=0.00
# Ep 179	 done after 30 iteractions	 epsilon=0.00
# Ep 180	 done after 114 iteractions	 epsilon=0.00
# Ep 181	 done after 119 iteractions	 epsilon=0.00
# Ep 182	 done after 11 iteractions	 epsilon=0.00
# Ep 183	 done after 12 iteractions	 epsilon=0.00
# Ep 184	 done after 15 iteractions	 epsilon=0.00
# Ep 185	 done after 26 iteractions	 epsilon=0.00
# Ep 186	 done after 10 iteractions	 epsilon=0.00
# Ep 187	 done after 20 iteractions	 epsilon=0.00
# Ep 188	 done after 14 iteractions	 epsilon=0.00
# Ep 189	 done after 12 iteractions	 epsilon=0.00
# Ep 190	 done after 27 iteractions	 epsilon=0.00
# Ep 191	 done after 10 iteractions	 epsilon=0.00
# Ep 192	 done after 12 iteractions	 epsilon=0.00
# Ep 193	 done after 14 iteractions	 epsilon=0.00
# Ep 194	 done after 23 iteractions	 epsilon=0.00
# Ep 195	 done after 132 iteractions	 epsilon=0.00
# Ep 196	 done after 34 iteractions	 epsilon=0.00
# Ep 197	 done after 41 iteractions	 epsilon=0.00
# Ep 198	 done after 47 iteractions	 epsilon=0.00
# Ep 199	 done after 68 iteractions	 epsilon=0.00
# Ep 200	 done after 11 iteractions	 epsilon=0.00
# Ep 201	 done after 103 iteractions	 epsilon=0.00
# Ep 202	 done after 77 iteractions	 epsilon=0.00
# Ep 203	 done after 46 iteractions	 epsilon=0.00
# Ep 204	 done after 76 iteractions	 epsilon=0.00
# Ep 205	 done after 10 iteractions	 epsilon=0.00
# Ep 206	 done after 9 iteractions	 epsilon=0.00
# Ep 207	 done after 69 iteractions	 epsilon=0.00
# Ep 208	 done after 13 iteractions	 epsilon=0.00
# Ep 209	 done after 84 iteractions	 epsilon=0.00
# Ep 210	 done after 39 iteractions	 epsilon=0.00
# Ep 211	 done after 11 iteractions	 epsilon=0.00
# Ep 212	 done after 55 iteractions	 epsilon=0.00
# Ep 213	 done after 9 iteractions	 epsilon=0.00
# Ep 214	 done after 60 iteractions	 epsilon=0.00
# Ep 215	 done after 128 iteractions	 epsilon=0.00
# Ep 216	 done after 84 iteractions	 epsilon=0.00
# Ep 217	 done after 10 iteractions	 epsilon=0.00
# Ep 218	 done after 17 iteractions	 epsilon=0.00
# Ep 219	 done after 10 iteractions	 epsilon=0.00
# Ep 220	 done after 53 iteractions	 epsilon=0.00
# Ep 221	 done after 15 iteractions	 epsilon=0.00
# Ep 222	 done after 10 iteractions	 epsilon=0.00
# Ep 223	 done after 17 iteractions	 epsilon=0.00
# Ep 224	 done after 23 iteractions	 epsilon=0.00
# Ep 225	 done after 25 iteractions	 epsilon=0.00
# Ep 226	 done after 33 iteractions	 epsilon=0.00
# Ep 227	 done after 15 iteractions	 epsilon=0.00
# Ep 228	 done after 11 iteractions	 epsilon=0.00
# Ep 229	 done after 9 iteractions	 epsilon=0.00
# Ep 230	 done after 16 iteractions	 epsilon=0.00
# Ep 231	 done after 15 iteractions	 epsilon=0.00
# Ep 232	 done after 6 iteractions	 epsilon=0.00
# Ep 233	 done after 15 iteractions	 epsilon=0.00
# Ep 234	 done after 102 iteractions	 epsilon=0.00
# Ep 235	 done after 151 iteractions	 epsilon=0.00
# Ep 236	 done after 10 iteractions	 epsilon=0.00
# Ep 237	 done after 10 iteractions	 epsilon=0.00
# Ep 238	 done after 60 iteractions	 epsilon=0.00
# Ep 239	 done after 12 iteractions	 epsilon=0.00
# Ep 240	 done after 13 iteractions	 epsilon=0.00
# Ep 241	 done after 65 iteractions	 epsilon=0.00
# Ep 242	 done after 61 iteractions	 epsilon=0.00
# Ep 243	 done after 33 iteractions	 epsilon=0.00
# Ep 244	 done after 45 iteractions	 epsilon=0.00
# Ep 245	 done after 24 iteractions	 epsilon=0.00
# Ep 246	 done after 14 iteractions	 epsilon=0.00
# Ep 247	 done after 67 iteractions	 epsilon=0.00
# Ep 248	 done after 16 iteractions	 epsilon=0.00
# Ep 249	 done after 65 iteractions	 epsilon=0.00
# Ep 250	 done after 17 iteractions	 epsilon=0.00
# Ep 251	 done after 41 iteractions	 epsilon=0.00
# Ep 252	 done after 14 iteractions	 epsilon=0.00
# Ep 253	 done after 9 iteractions	 epsilon=0.00
# Ep 254	 done after 29 iteractions	 epsilon=0.00
# Ep 255	 done after 22 iteractions	 epsilon=0.00
# Ep 256	 done after 20 iteractions	 epsilon=0.00
# Ep 257	 done after 65 iteractions	 epsilon=0.00
# Ep 258	 done after 48 iteractions	 epsilon=0.00
# Ep 259	 done after 10 iteractions	 epsilon=0.00
# Ep 260	 done after 21 iteractions	 epsilon=0.00
# Ep 261	 done after 17 iteractions	 epsilon=0.00
# Ep 262	 done after 9 iteractions	 epsilon=0.00
# Ep 263	 done after 33 iteractions	 epsilon=0.00
# Ep 264	 done after 9 iteractions	 epsilon=0.00
# Ep 265	 done after 18 iteractions	 epsilon=0.00
# Ep 266	 done after 11 iteractions	 epsilon=0.00
# Ep 267	 done after 10 iteractions	 epsilon=0.00
# Ep 268	 done after 24 iteractions	 epsilon=0.00
# Ep 269	 done after 27 iteractions	 epsilon=0.00
# Ep 270	 done after 28 iteractions	 epsilon=0.00
# Ep 271	 done after 16 iteractions	 epsilon=0.00
# Ep 272	 done after 8 iteractions	 epsilon=0.00
# Ep 273	 done after 11 iteractions	 epsilon=0.00
# Ep 274	 done after 25 iteractions	 epsilon=0.00
# Ep 275	 done after 11 iteractions	 epsilon=0.00
# Ep 276	 done after 16 iteractions	 epsilon=0.00
# Ep 277	 done after 12 iteractions	 epsilon=0.00
# Ep 278	 done after 29 iteractions	 epsilon=0.00
# Ep 279	 done after 15 iteractions	 epsilon=0.00
# Ep 280	 done after 15 iteractions	 epsilon=0.00
# Ep 281	 done after 11 iteractions	 epsilon=0.00
# Ep 282	 done after 8 iteractions	 epsilon=0.00
# Ep 283	 done after 12 iteractions	 epsilon=0.00
# Ep 284	 done after 35 iteractions	 epsilon=0.00
# Ep 285	 done after 20 iteractions	 epsilon=0.00
# Ep 286	 done after 19 iteractions	 epsilon=0.00
# Ep 287	 done after 14 iteractions	 epsilon=0.00
# Ep 288	 done after 15 iteractions	 epsilon=0.00
# Ep 289	 done after 24 iteractions	 epsilon=0.00
# Ep 290	 done after 12 iteractions	 epsilon=0.00
# Ep 291	 done after 13 iteractions	 epsilon=0.00
# Ep 292	 done after 11 iteractions	 epsilon=0.00
# Ep 293	 done after 13 iteractions	 epsilon=0.00
# Ep 294	 done after 12 iteractions	 epsilon=0.00
# Ep 295	 done after 27 iteractions	 epsilon=0.00
# Ep 296	 done after 16 iteractions	 epsilon=0.00
# Ep 297	 done after 10 iteractions	 epsilon=0.00
# Ep 298	 done after 33 iteractions	 epsilon=0.00
# Ep 299	 done after 26 iteractions	 epsilon=0.00
# Ep 300	 done after 9 iteractions	 epsilon=0.00
# Ep 301	 done after 17 iteractions	 epsilon=0.00
# Ep 302	 done after 11 iteractions	 epsilon=0.00
# Ep 303	 done after 8 iteractions	 epsilon=0.00
# Ep 304	 done after 8 iteractions	 epsilon=0.00
# Ep 305	 done after 14 iteractions	 epsilon=0.00
# Ep 306	 done after 54 iteractions	 epsilon=0.00
# Ep 307	 done after 21 iteractions	 epsilon=0.00
# Ep 308	 done after 26 iteractions	 epsilon=0.00
# Ep 309	 done after 63 iteractions	 epsilon=0.00
# Ep 310	 done after 12 iteractions	 epsilon=0.00
# Ep 311	 done after 18 iteractions	 epsilon=0.00
# Ep 312	 done after 32 iteractions	 epsilon=0.00
# Ep 313	 done after 27 iteractions	 epsilon=0.00
# Ep 314	 done after 10 iteractions	 epsilon=0.00
# Ep 315	 done after 26 iteractions	 epsilon=0.00
# Ep 316	 done after 25 iteractions	 epsilon=0.00
# Ep 317	 done after 17 iteractions	 epsilon=0.00
# Ep 318	 done after 9 iteractions	 epsilon=0.00
# Ep 319	 done after 7 iteractions	 epsilon=0.00
# Ep 320	 done after 12 iteractions	 epsilon=0.00
# Ep 321	 done after 35 iteractions	 epsilon=0.00
# Ep 322	 done after 14 iteractions	 epsilon=0.00
# Ep 323	 done after 17 iteractions	 epsilon=0.00
# Ep 324	 done after 50 iteractions	 epsilon=0.00
# Ep 325	 done after 30 iteractions	 epsilon=0.00
# Ep 326	 done after 27 iteractions	 epsilon=0.00
# Ep 327	 done after 15 iteractions	 epsilon=0.00
# Ep 328	 done after 12 iteractions	 epsilon=0.00
# Ep 329	 done after 26 iteractions	 epsilon=0.00
# Ep 330	 done after 21 iteractions	 epsilon=0.00
# Ep 331	 done after 13 iteractions	 epsilon=0.00
# Ep 332	 done after 14 iteractions	 epsilon=0.00
# Ep 333	 done after 17 iteractions	 epsilon=0.00
# Ep 334	 done after 10 iteractions	 epsilon=0.00
# Ep 335	 done after 10 iteractions	 epsilon=0.00
# Ep 336	 done after 9 iteractions	 epsilon=0.00
# Ep 337	 done after 15 iteractions	 epsilon=0.00
# Ep 338	 done after 17 iteractions	 epsilon=0.00
# Ep 339	 done after 40 iteractions	 epsilon=0.00
# Ep 340	 done after 15 iteractions	 epsilon=0.00
# Ep 341	 done after 12 iteractions	 epsilon=0.00
# Ep 342	 done after 12 iteractions	 epsilon=0.00
# Ep 343	 done after 10 iteractions	 epsilon=0.00
# Ep 344	 done after 13 iteractions	 epsilon=0.00
# Ep 345	 done after 29 iteractions	 epsilon=0.00
# Ep 346	 done after 13 iteractions	 epsilon=0.00
# Ep 347	 done after 19 iteractions	 epsilon=0.00
# Ep 348	 done after 30 iteractions	 epsilon=0.00
# Ep 349	 done after 19 iteractions	 epsilon=0.00
# Ep 350	 done after 24 iteractions	 epsilon=0.00
# Ep 351	 done after 10 iteractions	 epsilon=0.00
# Ep 352	 done after 18 iteractions	 epsilon=0.00
# Ep 353	 done after 20 iteractions	 epsilon=0.00
# Ep 354	 done after 7 iteractions	 epsilon=0.00
# Ep 355	 done after 27 iteractions	 epsilon=0.00
# Ep 356	 done after 10 iteractions	 epsilon=0.00
# Ep 357	 done after 12 iteractions	 epsilon=0.00
# Ep 358	 done after 11 iteractions	 epsilon=0.00
# Ep 359	 done after 13 iteractions	 epsilon=0.00
# Ep 360	 done after 16 iteractions	 epsilon=0.00
# Ep 361	 done after 20 iteractions	 epsilon=0.00
# Ep 362	 done after 12 iteractions	 epsilon=0.00
# Ep 363	 done after 27 iteractions	 epsilon=0.00
# Ep 364	 done after 17 iteractions	 epsilon=0.00
# Ep 365	 done after 14 iteractions	 epsilon=0.00
# Ep 366	 done after 18 iteractions	 epsilon=0.00
# Ep 367	 done after 10 iteractions	 epsilon=0.00
# Ep 368	 done after 11 iteractions	 epsilon=0.00
# Ep 369	 done after 14 iteractions	 epsilon=0.00
# Ep 370	 done after 16 iteractions	 epsilon=0.00
# Ep 371	 done after 17 iteractions	 epsilon=0.00
# Ep 372	 done after 13 iteractions	 epsilon=0.00
# Ep 373	 done after 13 iteractions	 epsilon=0.00
# Ep 374	 done after 17 iteractions	 epsilon=0.00
# Ep 375	 done after 16 iteractions	 epsilon=0.00
# Ep 376	 done after 35 iteractions	 epsilon=0.00
# Ep 377	 done after 12 iteractions	 epsilon=0.00
# Ep 378	 done after 15 iteractions	 epsilon=0.00
# Ep 379	 done after 13 iteractions	 epsilon=0.00
# Ep 380	 done after 21 iteractions	 epsilon=0.00
# Ep 381	 done after 11 iteractions	 epsilon=0.00
# Ep 382	 done after 14 iteractions	 epsilon=0.00
# Ep 383	 done after 14 iteractions	 epsilon=0.00
# Ep 384	 done after 27 iteractions	 epsilon=0.00
# Ep 385	 done after 14 iteractions	 epsilon=0.00
# Ep 386	 done after 30 iteractions	 epsilon=0.00
# Ep 387	 done after 11 iteractions	 epsilon=0.00
# Ep 388	 done after 16 iteractions	 epsilon=0.00
# Ep 389	 done after 14 iteractions	 epsilon=0.00
# Ep 390	 done after 17 iteractions	 epsilon=0.00
# Ep 391	 done after 11 iteractions	 epsilon=0.00
# Ep 392	 done after 9 iteractions	 epsilon=0.00
# Ep 393	 done after 11 iteractions	 epsilon=0.00
# Ep 394	 done after 16 iteractions	 epsilon=0.00
# Ep 395	 done after 16 iteractions	 epsilon=0.00
# Ep 396	 done after 16 iteractions	 epsilon=0.00
# Ep 397	 done after 12 iteractions	 epsilon=0.00
# Ep 398	 done after 14 iteractions	 epsilon=0.00
# Ep 399	 done after 8 iteractions	 epsilon=0.00
# Ep 400	 done after 12 iteractions	 epsilon=0.00
# Ep 401	 done after 8 iteractions	 epsilon=0.00
# Ep 402	 done after 8 iteractions	 epsilon=0.00
# Ep 403	 done after 13 iteractions	 epsilon=0.00
# Ep 404	 done after 25 iteractions	 epsilon=0.00
# Ep 405	 done after 25 iteractions	 epsilon=0.00
# Ep 406	 done after 15 iteractions	 epsilon=0.00
# Ep 407	 done after 16 iteractions	 epsilon=0.00
# Ep 408	 done after 9 iteractions	 epsilon=0.00
# Ep 409	 done after 13 iteractions	 epsilon=0.00
# Ep 410	 done after 11 iteractions	 epsilon=0.00
# Ep 411	 done after 26 iteractions	 epsilon=0.00
# Ep 412	 done after 14 iteractions	 epsilon=0.00
# Ep 413	 done after 10 iteractions	 epsilon=0.00
# Ep 414	 done after 12 iteractions	 epsilon=0.00
# Ep 415	 done after 16 iteractions	 epsilon=0.00
# Ep 416	 done after 8 iteractions	 epsilon=0.00
# Ep 417	 done after 22 iteractions	 epsilon=0.00
# Ep 418	 done after 8 iteractions	 epsilon=0.00
# Ep 419	 done after 25 iteractions	 epsilon=0.00
# Ep 420	 done after 15 iteractions	 epsilon=0.00
# Ep 421	 done after 16 iteractions	 epsilon=0.00
# Ep 422	 done after 9 iteractions	 epsilon=0.00
# Ep 423	 done after 10 iteractions	 epsilon=0.00
# Ep 424	 done after 22 iteractions	 epsilon=0.00
# Ep 425	 done after 12 iteractions	 epsilon=0.00
# Ep 426	 done after 12 iteractions	 epsilon=0.00
# Ep 427	 done after 15 iteractions	 epsilon=0.00
# Ep 428	 done after 14 iteractions	 epsilon=0.00
# Ep 429	 done after 13 iteractions	 epsilon=0.00
# Ep 430	 done after 11 iteractions	 epsilon=0.00
# Ep 431	 done after 14 iteractions	 epsilon=0.00
# Ep 432	 done after 9 iteractions	 epsilon=0.00
# Ep 433	 done after 12 iteractions	 epsilon=0.00
# Ep 434	 done after 20 iteractions	 epsilon=0.00
# Ep 435	 done after 17 iteractions	 epsilon=0.00
# Ep 436	 done after 20 iteractions	 epsilon=0.00
# Ep 437	 done after 20 iteractions	 epsilon=0.00
# Ep 438	 done after 13 iteractions	 epsilon=0.00
# Ep 439	 done after 12 iteractions	 epsilon=0.00
# Ep 440	 done after 15 iteractions	 epsilon=0.00
# Ep 441	 done after 18 iteractions	 epsilon=0.00
# Ep 442	 done after 13 iteractions	 epsilon=0.00
# Ep 443	 done after 14 iteractions	 epsilon=0.00
# Ep 444	 done after 26 iteractions	 epsilon=0.00
# Ep 445	 done after 17 iteractions	 epsilon=0.00
# Ep 446	 done after 11 iteractions	 epsilon=0.00
# Ep 447	 done after 15 iteractions	 epsilon=0.00
# Ep 448	 done after 11 iteractions	 epsilon=0.00
# Ep 449	 done after 15 iteractions	 epsilon=0.00
# Ep 450	 done after 23 iteractions	 epsilon=0.00
# Ep 451	 done after 10 iteractions	 epsilon=0.00
# Ep 452	 done after 14 iteractions	 epsilon=0.00
# Ep 453	 done after 13 iteractions	 epsilon=0.00
# Ep 454	 done after 20 iteractions	 epsilon=0.00
# Ep 455	 done after 13 iteractions	 epsilon=0.00
# Ep 456	 done after 9 iteractions	 epsilon=0.00
# Ep 457	 done after 23 iteractions	 epsilon=0.00
# Ep 458	 done after 13 iteractions	 epsilon=0.00
# Ep 459	 done after 10 iteractions	 epsilon=0.00
# Ep 460	 done after 16 iteractions	 epsilon=0.00
# Ep 461	 done after 23 iteractions	 epsilon=0.00
# Ep 462	 done after 13 iteractions	 epsilon=0.00
# Ep 463	 done after 17 iteractions	 epsilon=0.00
# Ep 464	 done after 15 iteractions	 epsilon=0.00
# Ep 465	 done after 15 iteractions	 epsilon=0.00
# Ep 466	 done after 13 iteractions	 epsilon=0.00
# Ep 467	 done after 16 iteractions	 epsilon=0.00
# Ep 468	 done after 16 iteractions	 epsilon=0.00
# Ep 469	 done after 18 iteractions	 epsilon=0.00
# Ep 470	 done after 15 iteractions	 epsilon=0.00
# Ep 471	 done after 9 iteractions	 epsilon=0.00
# Ep 472	 done after 12 iteractions	 epsilon=0.00
# Ep 473	 done after 18 iteractions	 epsilon=0.00
# Ep 474	 done after 14 iteractions	 epsilon=0.00
# Ep 475	 done after 17 iteractions	 epsilon=0.00
# Ep 476	 done after 14 iteractions	 epsilon=0.00
# Ep 477	 done after 13 iteractions	 epsilon=0.00
# Ep 478	 done after 10 iteractions	 epsilon=0.00
# Ep 479	 done after 14 iteractions	 epsilon=0.00
# Ep 480	 done after 7 iteractions	 epsilon=0.00
# Ep 481	 done after 9 iteractions	 epsilon=0.00
# Ep 482	 done after 12 iteractions	 epsilon=0.00
# Ep 483	 done after 23 iteractions	 epsilon=0.00
# Ep 484	 done after 11 iteractions	 epsilon=0.00
# Ep 485	 done after 14 iteractions	 epsilon=0.00
# Ep 486	 done after 10 iteractions	 epsilon=0.00
# Ep 487	 done after 11 iteractions	 epsilon=0.00
# Ep 488	 done after 8 iteractions	 epsilon=0.00
# Ep 489	 done after 7 iteractions	 epsilon=0.00
# Ep 490	 done after 18 iteractions	 epsilon=0.00
# Ep 491	 done after 13 iteractions	 epsilon=0.00
# Ep 492	 done after 12 iteractions	 epsilon=0.00
# Ep 493	 done after 10 iteractions	 epsilon=0.00
# Ep 494	 done after 14 iteractions	 epsilon=0.00
# Ep 495	 done after 15 iteractions	 epsilon=0.00
# Ep 496	 done after 13 iteractions	 epsilon=0.00
# Ep 497	 done after 17 iteractions	 epsilon=0.00
# Ep 498	 done after 15 iteractions	 epsilon=0.00
# Ep 499	 done after 14 iteractions	 epsilon=0.00
# Ep 500	 done after 14 iteractions	 epsilon=0.00
# Ep 501	 done after 8 iteractions	 epsilon=0.00
# Ep 502	 done after 11 iteractions	 epsilon=0.00
# Ep 503	 done after 8 iteractions	 epsilon=0.00
# Ep 504	 done after 14 iteractions	 epsilon=0.00
# Ep 505	 done after 15 iteractions	 epsilon=0.00
# Ep 506	 done after 10 iteractions	 epsilon=0.00
# Ep 507	 done after 16 iteractions	 epsilon=0.00
# Ep 508	 done after 12 iteractions	 epsilon=0.00
# Ep 509	 done after 11 iteractions	 epsilon=0.00
# Ep 510	 done after 16 iteractions	 epsilon=0.00
# Ep 511	 done after 10 iteractions	 epsilon=0.00
# Ep 512	 done after 12 iteractions	 epsilon=0.00
# Ep 513	 done after 27 iteractions	 epsilon=0.00
# Ep 514	 done after 8 iteractions	 epsilon=0.00
# Ep 515	 done after 9 iteractions	 epsilon=0.00
# Ep 516	 done after 18 iteractions	 epsilon=0.00
# Ep 517	 done after 11 iteractions	 epsilon=0.00
# Ep 518	 done after 16 iteractions	 epsilon=0.00
# Ep 519	 done after 13 iteractions	 epsilon=0.00
# Ep 520	 done after 10 iteractions	 epsilon=0.00
# Ep 521	 done after 19 iteractions	 epsilon=0.00
# Ep 522	 done after 10 iteractions	 epsilon=0.00
# Ep 523	 done after 19 iteractions	 epsilon=0.00
# Ep 524	 done after 10 iteractions	 epsilon=0.00
# Ep 525	 done after 13 iteractions	 epsilon=0.00
# Ep 526	 done after 12 iteractions	 epsilon=0.00
# Ep 527	 done after 13 iteractions	 epsilon=0.00
# Ep 528	 done after 11 iteractions	 epsilon=0.00
# Ep 529	 done after 8 iteractions	 epsilon=0.00
# Ep 530	 done after 13 iteractions	 epsilon=0.00
# Ep 531	 done after 10 iteractions	 epsilon=0.00
# Ep 532	 done after 21 iteractions	 epsilon=0.00
# Ep 533	 done after 19 iteractions	 epsilon=0.00
# Ep 534	 done after 13 iteractions	 epsilon=0.00
# Ep 535	 done after 14 iteractions	 epsilon=0.00
# Ep 536	 done after 15 iteractions	 epsilon=0.00
# Ep 537	 done after 9 iteractions	 epsilon=0.00
# Ep 538	 done after 16 iteractions	 epsilon=0.00
# Ep 539	 done after 14 iteractions	 epsilon=0.00
# Ep 540	 done after 7 iteractions	 epsilon=0.00
# Ep 541	 done after 17 iteractions	 epsilon=0.00
# Ep 542	 done after 16 iteractions	 epsilon=0.00
# Ep 543	 done after 11 iteractions	 epsilon=0.00
# Ep 544	 done after 14 iteractions	 epsilon=0.00
# Ep 545	 done after 9 iteractions	 epsilon=0.00
# Ep 546	 done after 10 iteractions	 epsilon=0.00
# Ep 547	 done after 10 iteractions	 epsilon=0.00
# Ep 548	 done after 12 iteractions	 epsilon=0.00
# Ep 549	 done after 22 iteractions	 epsilon=0.00
# Ep 550	 done after 15 iteractions	 epsilon=0.00
# Ep 551	 done after 23 iteractions	 epsilon=0.00
# Ep 552	 done after 10 iteractions	 epsilon=0.00
# Ep 553	 done after 6 iteractions	 epsilon=0.00
# Ep 554	 done after 9 iteractions	 epsilon=0.00
# Ep 555	 done after 15 iteractions	 epsilon=0.00
# Ep 556	 done after 18 iteractions	 epsilon=0.00
# Ep 557	 done after 13 iteractions	 epsilon=0.00
# Ep 558	 done after 9 iteractions	 epsilon=0.00
# Ep 559	 done after 18 iteractions	 epsilon=0.00
# Ep 560	 done after 15 iteractions	 epsilon=0.00
# Ep 561	 done after 10 iteractions	 epsilon=0.00
# Ep 562	 done after 13 iteractions	 epsilon=0.00
# Ep 563	 done after 12 iteractions	 epsilon=0.00
# Ep 564	 done after 13 iteractions	 epsilon=0.00
# Ep 565	 done after 17 iteractions	 epsilon=0.00
# Ep 566	 done after 13 iteractions	 epsilon=0.00
# Ep 567	 done after 12 iteractions	 epsilon=0.00
# Ep 568	 done after 12 iteractions	 epsilon=0.00
# Ep 569	 done after 7 iteractions	 epsilon=0.00
# Ep 570	 done after 13 iteractions	 epsilon=0.00
# Ep 571	 done after 15 iteractions	 epsilon=0.00
# Ep 572	 done after 9 iteractions	 epsilon=0.00
# Ep 573	 done after 8 iteractions	 epsilon=0.00
# Ep 574	 done after 9 iteractions	 epsilon=0.00
# Ep 575	 done after 16 iteractions	 epsilon=0.00
# Ep 576	 done after 12 iteractions	 epsilon=0.00
# Ep 577	 done after 19 iteractions	 epsilon=0.00
# Ep 578	 done after 14 iteractions	 epsilon=0.00
# Ep 579	 done after 11 iteractions	 epsilon=0.00
# Ep 580	 done after 14 iteractions	 epsilon=0.00
# Ep 581	 done after 9 iteractions	 epsilon=0.00
# Ep 582	 done after 11 iteractions	 epsilon=0.00
# Ep 583	 done after 15 iteractions	 epsilon=0.00
# Ep 584	 done after 14 iteractions	 epsilon=0.00
# Ep 585	 done after 22 iteractions	 epsilon=0.00
# Ep 586	 done after 15 iteractions	 epsilon=0.00
# Ep 587	 done after 12 iteractions	 epsilon=0.00
# Ep 588	 done after 11 iteractions	 epsilon=0.00
# Ep 589	 done after 14 iteractions	 epsilon=0.00
# Ep 590	 done after 7 iteractions	 epsilon=0.00
# Ep 591	 done after 6 iteractions	 epsilon=0.00
# Ep 592	 done after 7 iteractions	 epsilon=0.00
# Ep 593	 done after 14 iteractions	 epsilon=0.00
# Ep 594	 done after 14 iteractions	 epsilon=0.00
# Ep 595	 done after 10 iteractions	 epsilon=0.00
# Ep 596	 done after 17 iteractions	 epsilon=0.00
# Ep 597	 done after 12 iteractions	 epsilon=0.00
# Ep 598	 done after 10 iteractions	 epsilon=0.00
# Ep 599	 done after 17 iteractions	 epsilon=0.00
# Ep 600	 done after 7 iteractions	 epsilon=0.00
# Ep 601	 done after 9 iteractions	 epsilon=0.00
# Ep 602	 done after 11 iteractions	 epsilon=0.00
# Ep 603	 done after 15 iteractions	 epsilon=0.00
# Ep 604	 done after 13 iteractions	 epsilon=0.00
# Ep 605	 done after 16 iteractions	 epsilon=0.00
# Ep 606	 done after 10 iteractions	 epsilon=0.00
# Ep 607	 done after 22 iteractions	 epsilon=0.00
# Ep 608	 done after 9 iteractions	 epsilon=0.00
# Ep 609	 done after 13 iteractions	 epsilon=0.00
# Ep 610	 done after 9 iteractions	 epsilon=0.00
# Ep 611	 done after 12 iteractions	 epsilon=0.00
# Ep 612	 done after 14 iteractions	 epsilon=0.00
# Ep 613	 done after 8 iteractions	 epsilon=0.00
# Ep 614	 done after 14 iteractions	 epsilon=0.00
# Ep 615	 done after 28 iteractions	 epsilon=0.00
# Ep 616	 done after 16 iteractions	 epsilon=0.00
# Ep 617	 done after 12 iteractions	 epsilon=0.00
# Ep 618	 done after 13 iteractions	 epsilon=0.00
# Ep 619	 done after 15 iteractions	 epsilon=0.00
# Ep 620	 done after 10 iteractions	 epsilon=0.00
# Ep 621	 done after 13 iteractions	 epsilon=0.00
# Ep 622	 done after 21 iteractions	 epsilon=0.00
# Ep 623	 done after 10 iteractions	 epsilon=0.00
# Ep 624	 done after 15 iteractions	 epsilon=0.00
# Ep 625	 done after 16 iteractions	 epsilon=0.00
# Ep 626	 done after 16 iteractions	 epsilon=0.00
# Ep 627	 done after 16 iteractions	 epsilon=0.00
# Ep 628	 done after 16 iteractions	 epsilon=0.00
# Ep 629	 done after 15 iteractions	 epsilon=0.00
# Ep 630	 done after 12 iteractions	 epsilon=0.00
# Ep 631	 done after 16 iteractions	 epsilon=0.00
# Ep 632	 done after 14 iteractions	 epsilon=0.00
# Ep 633	 done after 16 iteractions	 epsilon=0.00
# Ep 634	 done after 10 iteractions	 epsilon=0.00
# Ep 635	 done after 16 iteractions	 epsilon=0.00
# Ep 636	 done after 7 iteractions	 epsilon=0.00
# Ep 637	 done after 14 iteractions	 epsilon=0.00
# Ep 638	 done after 6 iteractions	 epsilon=0.00
# Ep 639	 done after 13 iteractions	 epsilon=0.00
# Ep 640	 done after 12 iteractions	 epsilon=0.00
# Ep 641	 done after 17 iteractions	 epsilon=0.00
# Ep 642	 done after 16 iteractions	 epsilon=0.00
# Ep 643	 done after 11 iteractions	 epsilon=0.00
# Ep 644	 done after 13 iteractions	 epsilon=0.00
# Ep 645	 done after 10 iteractions	 epsilon=0.00
# Ep 646	 done after 13 iteractions	 epsilon=0.00
# Ep 647	 done after 10 iteractions	 epsilon=0.00
# Ep 648	 done after 10 iteractions	 epsilon=0.00
# Ep 649	 done after 14 iteractions	 epsilon=0.00
# Ep 650	 done after 9 iteractions	 epsilon=0.00
# Ep 651	 done after 9 iteractions	 epsilon=0.00
# Ep 652	 done after 10 iteractions	 epsilon=0.00
# Ep 653	 done after 18 iteractions	 epsilon=0.00
# Ep 654	 done after 21 iteractions	 epsilon=0.00
# Ep 655	 done after 12 iteractions	 epsilon=0.00
# Ep 656	 done after 13 iteractions	 epsilon=0.00
# Ep 657	 done after 26 iteractions	 epsilon=0.00
# Ep 658	 done after 10 iteractions	 epsilon=0.00
# Ep 659	 done after 15 iteractions	 epsilon=0.00
# Ep 660	 done after 13 iteractions	 epsilon=0.00
# Ep 661	 done after 12 iteractions	 epsilon=0.00
# Ep 662	 done after 14 iteractions	 epsilon=0.00
# Ep 663	 done after 11 iteractions	 epsilon=0.00
# Ep 664	 done after 10 iteractions	 epsilon=0.00
# Ep 665	 done after 16 iteractions	 epsilon=0.00
# Ep 666	 done after 11 iteractions	 epsilon=0.00
# Ep 667	 done after 16 iteractions	 epsilon=0.00
# Ep 668	 done after 12 iteractions	 epsilon=0.00
# Ep 669	 done after 9 iteractions	 epsilon=0.00
# Ep 670	 done after 11 iteractions	 epsilon=0.00
# Ep 671	 done after 11 iteractions	 epsilon=0.00
# Ep 672	 done after 14 iteractions	 epsilon=0.00
# Ep 673	 done after 14 iteractions	 epsilon=0.00
# Ep 674	 done after 13 iteractions	 epsilon=0.00
# Ep 675	 done after 12 iteractions	 epsilon=0.00
# Ep 676	 done after 17 iteractions	 epsilon=0.00
# Ep 677	 done after 13 iteractions	 epsilon=0.00
# Ep 678	 done after 12 iteractions	 epsilon=0.00
# Ep 679	 done after 11 iteractions	 epsilon=0.00
# Ep 680	 done after 14 iteractions	 epsilon=0.00
# Ep 681	 done after 16 iteractions	 epsilon=0.00
# Ep 682	 done after 15 iteractions	 epsilon=0.00
# Ep 683	 done after 16 iteractions	 epsilon=0.00
# Ep 684	 done after 17 iteractions	 epsilon=0.00
# Ep 685	 done after 10 iteractions	 epsilon=0.00
# Ep 686	 done after 11 iteractions	 epsilon=0.00
# Ep 687	 done after 18 iteractions	 epsilon=0.00
# Ep 688	 done after 16 iteractions	 epsilon=0.00
# Ep 689	 done after 15 iteractions	 epsilon=0.00
# Ep 690	 done after 16 iteractions	 epsilon=0.00
# Ep 691	 done after 18 iteractions	 epsilon=0.00
# Ep 692	 done after 13 iteractions	 epsilon=0.00
# Ep 693	 done after 15 iteractions	 epsilon=0.00
# Ep 694	 done after 11 iteractions	 epsilon=0.00
# Ep 695	 done after 10 iteractions	 epsilon=0.00
# Ep 696	 done after 18 iteractions	 epsilon=0.00
# Ep 697	 done after 15 iteractions	 epsilon=0.00
# Ep 698	 done after 14 iteractions	 epsilon=0.00
# Ep 699	 done after 24 iteractions	 epsilon=0.00
# Ep 700	 done after 14 iteractions	 epsilon=0.00
# Ep 701	 done after 11 iteractions	 epsilon=0.00
# Ep 702	 done after 10 iteractions	 epsilon=0.00
# Ep 703	 done after 15 iteractions	 epsilon=0.00
# Ep 704	 done after 14 iteractions	 epsilon=0.00
# Ep 705	 done after 8 iteractions	 epsilon=0.00
# Ep 706	 done after 10 iteractions	 epsilon=0.00
# Ep 707	 done after 14 iteractions	 epsilon=0.00
# Ep 708	 done after 10 iteractions	 epsilon=0.00
# Ep 709	 done after 10 iteractions	 epsilon=0.00
# Ep 710	 done after 10 iteractions	 epsilon=0.00
# Ep 711	 done after 14 iteractions	 epsilon=0.00
# Ep 712	 done after 14 iteractions	 epsilon=0.00
# Ep 713	 done after 15 iteractions	 epsilon=0.00
# Ep 714	 done after 11 iteractions	 epsilon=0.00
# Ep 715	 done after 15 iteractions	 epsilon=0.00
# Ep 716	 done after 10 iteractions	 epsilon=0.00
# Ep 717	 done after 15 iteractions	 epsilon=0.00
# Ep 718	 done after 11 iteractions	 epsilon=0.00
# Ep 719	 done after 9 iteractions	 epsilon=0.00
# Ep 720	 done after 12 iteractions	 epsilon=0.00
# Ep 721	 done after 11 iteractions	 epsilon=0.00
# Ep 722	 done after 13 iteractions	 epsilon=0.00
# Ep 723	 done after 12 iteractions	 epsilon=0.00
# Ep 724	 done after 8 iteractions	 epsilon=0.00
# Ep 725	 done after 15 iteractions	 epsilon=0.00
# Ep 726	 done after 10 iteractions	 epsilon=0.00
# Ep 727	 done after 11 iteractions	 epsilon=0.00
# Ep 728	 done after 13 iteractions	 epsilon=0.00
# Ep 729	 done after 17 iteractions	 epsilon=0.00
# Ep 730	 done after 13 iteractions	 epsilon=0.00
# Ep 731	 done after 18 iteractions	 epsilon=0.00
# Ep 732	 done after 9 iteractions	 epsilon=0.00
# Ep 733	 done after 10 iteractions	 epsilon=0.00
# Ep 734	 done after 13 iteractions	 epsilon=0.00
# Ep 735	 done after 10 iteractions	 epsilon=0.00
# Ep 736	 done after 14 iteractions	 epsilon=0.00
# Ep 737	 done after 9 iteractions	 epsilon=0.00
# Ep 738	 done after 17 iteractions	 epsilon=0.00
# Ep 739	 done after 12 iteractions	 epsilon=0.00
# Ep 740	 done after 17 iteractions	 epsilon=0.00
# Ep 741	 done after 14 iteractions	 epsilon=0.00
# Ep 742	 done after 10 iteractions	 epsilon=0.00
# Ep 743	 done after 12 iteractions	 epsilon=0.00
# Ep 744	 done after 30 iteractions	 epsilon=0.00
# Ep 745	 done after 26 iteractions	 epsilon=0.00
# Ep 746	 done after 17 iteractions	 epsilon=0.00
# Ep 747	 done after 14 iteractions	 epsilon=0.00
# Ep 748	 done after 12 iteractions	 epsilon=0.00
# Ep 749	 done after 11 iteractions	 epsilon=0.00
# Ep 750	 done after 9 iteractions	 epsilon=0.00
# Ep 751	 done after 12 iteractions	 epsilon=0.00
# Ep 752	 done after 10 iteractions	 epsilon=0.00
# Ep 753	 done after 18 iteractions	 epsilon=0.00
# Ep 754	 done after 12 iteractions	 epsilon=0.00
# Ep 755	 done after 12 iteractions	 epsilon=0.00
# Ep 756	 done after 13 iteractions	 epsilon=0.00
# Ep 757	 done after 16 iteractions	 epsilon=0.00
# Ep 758	 done after 12 iteractions	 epsilon=0.00
# Ep 759	 done after 9 iteractions	 epsilon=0.00
# Ep 760	 done after 9 iteractions	 epsilon=0.00
# Ep 761	 done after 14 iteractions	 epsilon=0.00
# Ep 762	 done after 10 iteractions	 epsilon=0.00
# Ep 763	 done after 10 iteractions	 epsilon=0.00
# Ep 764	 done after 14 iteractions	 epsilon=0.00
# Ep 765	 done after 15 iteractions	 epsilon=0.00
# Ep 766	 done after 11 iteractions	 epsilon=0.00
# Ep 767	 done after 16 iteractions	 epsilon=0.00
# Ep 768	 done after 15 iteractions	 epsilon=0.00
# Ep 769	 done after 16 iteractions	 epsilon=0.00
# Ep 770	 done after 14 iteractions	 epsilon=0.00
# Ep 771	 done after 15 iteractions	 epsilon=0.00
# Ep 772	 done after 17 iteractions	 epsilon=0.00
# Ep 773	 done after 14 iteractions	 epsilon=0.00
# Ep 774	 done after 14 iteractions	 epsilon=0.00
# Ep 775	 done after 17 iteractions	 epsilon=0.00
# Ep 776	 done after 10 iteractions	 epsilon=0.00
# Ep 777	 done after 9 iteractions	 epsilon=0.00
# Ep 778	 done after 12 iteractions	 epsilon=0.00
# Ep 779	 done after 12 iteractions	 epsilon=0.00
# Ep 780	 done after 9 iteractions	 epsilon=0.00
# Ep 781	 done after 11 iteractions	 epsilon=0.00
# Ep 782	 done after 14 iteractions	 epsilon=0.00
# Ep 783	 done after 14 iteractions	 epsilon=0.00
# Ep 784	 done after 15 iteractions	 epsilon=0.00
# Ep 785	 done after 13 iteractions	 epsilon=0.00
# Ep 786	 done after 14 iteractions	 epsilon=0.00
# Ep 787	 done after 18 iteractions	 epsilon=0.00
# Ep 788	 done after 14 iteractions	 epsilon=0.00
# Ep 789	 done after 13 iteractions	 epsilon=0.00
# Ep 790	 done after 15 iteractions	 epsilon=0.00
# Ep 791	 done after 13 iteractions	 epsilon=0.00
# Ep 792	 done after 17 iteractions	 epsilon=0.00
# Ep 793	 done after 15 iteractions	 epsilon=0.00
# Ep 794	 done after 14 iteractions	 epsilon=0.00
# Ep 795	 done after 14 iteractions	 epsilon=0.00
# Ep 796	 done after 9 iteractions	 epsilon=0.00
# Ep 797	 done after 12 iteractions	 epsilon=0.00
# Ep 798	 done after 13 iteractions	 epsilon=0.00
# Ep 799	 done after 10 iteractions	 epsilon=0.00
# Ep 800	 done after 9 iteractions	 epsilon=0.00
# Ep 801	 done after 12 iteractions	 epsilon=0.00
# Ep 802	 done after 13 iteractions	 epsilon=0.00
# Ep 803	 done after 14 iteractions	 epsilon=0.00
# Ep 804	 done after 13 iteractions	 epsilon=0.00
# Ep 805	 done after 14 iteractions	 epsilon=0.00
# Ep 806	 done after 14 iteractions	 epsilon=0.00
# Ep 807	 done after 10 iteractions	 epsilon=0.00
# Ep 808	 done after 14 iteractions	 epsilon=0.00
# Ep 809	 done after 9 iteractions	 epsilon=0.00
# Ep 810	 done after 14 iteractions	 epsilon=0.00
# Ep 811	 done after 14 iteractions	 epsilon=0.00
# Ep 812	 done after 10 iteractions	 epsilon=0.00
# Ep 813	 done after 8 iteractions	 epsilon=0.00
# Ep 814	 done after 13 iteractions	 epsilon=0.00
# Ep 815	 done after 13 iteractions	 epsilon=0.00
# Ep 816	 done after 12 iteractions	 epsilon=0.00
# Ep 817	 done after 9 iteractions	 epsilon=0.00
# Ep 818	 done after 6 iteractions	 epsilon=0.00
# Ep 819	 done after 20 iteractions	 epsilon=0.00
# Ep 820	 done after 14 iteractions	 epsilon=0.00
# Ep 821	 done after 12 iteractions	 epsilon=0.00
# Ep 822	 done after 13 iteractions	 epsilon=0.00
# Ep 823	 done after 9 iteractions	 epsilon=0.00
# Ep 824	 done after 14 iteractions	 epsilon=0.00
# Ep 825	 done after 16 iteractions	 epsilon=0.00
# Ep 826	 done after 14 iteractions	 epsilon=0.00
# Ep 827	 done after 11 iteractions	 epsilon=0.00
# Ep 828	 done after 13 iteractions	 epsilon=0.00
# Ep 829	 done after 21 iteractions	 epsilon=0.00
# Ep 830	 done after 11 iteractions	 epsilon=0.00
# Ep 831	 done after 14 iteractions	 epsilon=0.00
# Ep 832	 done after 14 iteractions	 epsilon=0.00
# Ep 833	 done after 10 iteractions	 epsilon=0.00
# Ep 834	 done after 8 iteractions	 epsilon=0.00
# Ep 835	 done after 10 iteractions	 epsilon=0.00
# Ep 836	 done after 10 iteractions	 epsilon=0.00
# Ep 837	 done after 15 iteractions	 epsilon=0.00
# Ep 838	 done after 12 iteractions	 epsilon=0.00
# Ep 839	 done after 16 iteractions	 epsilon=0.00
# Ep 840	 done after 16 iteractions	 epsilon=0.00
# Ep 841	 done after 12 iteractions	 epsilon=0.00
# Ep 842	 done after 12 iteractions	 epsilon=0.00
# Ep 843	 done after 16 iteractions	 epsilon=0.00
# Ep 844	 done after 16 iteractions	 epsilon=0.00
# Ep 845	 done after 15 iteractions	 epsilon=0.00
# Ep 846	 done after 12 iteractions	 epsilon=0.00
# Ep 847	 done after 15 iteractions	 epsilon=0.00
# Ep 848	 done after 10 iteractions	 epsilon=0.00
# Ep 849	 done after 10 iteractions	 epsilon=0.00
# Ep 850	 done after 17 iteractions	 epsilon=0.00
# Ep 851	 done after 15 iteractions	 epsilon=0.00
# Ep 852	 done after 14 iteractions	 epsilon=0.00
# Ep 853	 done after 13 iteractions	 epsilon=0.00
# Ep 854	 done after 11 iteractions	 epsilon=0.00
# Ep 855	 done after 18 iteractions	 epsilon=0.00
# Ep 856	 done after 12 iteractions	 epsilon=0.00
# Ep 857	 done after 16 iteractions	 epsilon=0.00
# Ep 858	 done after 18 iteractions	 epsilon=0.00
# Ep 859	 done after 7 iteractions	 epsilon=0.00
# Ep 860	 done after 14 iteractions	 epsilon=0.00
# Ep 861	 done after 17 iteractions	 epsilon=0.00
# Ep 862	 done after 16 iteractions	 epsilon=0.00
# Ep 863	 done after 14 iteractions	 epsilon=0.00
# Ep 864	 done after 16 iteractions	 epsilon=0.00
# Ep 865	 done after 12 iteractions	 epsilon=0.00
# Ep 866	 done after 14 iteractions	 epsilon=0.00
# Ep 867	 done after 13 iteractions	 epsilon=0.00
# Ep 868	 done after 16 iteractions	 epsilon=0.00
# Ep 869	 done after 14 iteractions	 epsilon=0.00
# Ep 870	 done after 18 iteractions	 epsilon=0.00
# Ep 871	 done after 12 iteractions	 epsilon=0.00
# Ep 872	 done after 11 iteractions	 epsilon=0.00
# Ep 873	 done after 10 iteractions	 epsilon=0.00
# Ep 874	 done after 15 iteractions	 epsilon=0.00
# Ep 875	 done after 13 iteractions	 epsilon=0.00
# Ep 876	 done after 15 iteractions	 epsilon=0.00
# Ep 877	 done after 16 iteractions	 epsilon=0.00
# Ep 878	 done after 13 iteractions	 epsilon=0.00
# Ep 879	 done after 14 iteractions	 epsilon=0.00
# Ep 880	 done after 16 iteractions	 epsilon=0.00
# Ep 881	 done after 11 iteractions	 epsilon=0.00
# Ep 882	 done after 18 iteractions	 epsilon=0.00
# Ep 883	 done after 14 iteractions	 epsilon=0.00
# Ep 884	 done after 14 iteractions	 epsilon=0.00
# Ep 885	 done after 17 iteractions	 epsilon=0.00
# Ep 886	 done after 16 iteractions	 epsilon=0.00
# Ep 887	 done after 9 iteractions	 epsilon=0.00
# Ep 888	 done after 14 iteractions	 epsilon=0.00
# Ep 889	 done after 11 iteractions	 epsilon=0.00
# Ep 890	 done after 13 iteractions	 epsilon=0.00
# Ep 891	 done after 11 iteractions	 epsilon=0.00
# Ep 892	 done after 14 iteractions	 epsilon=0.00
# Ep 893	 done after 12 iteractions	 epsilon=0.00
# Ep 894	 done after 11 iteractions	 epsilon=0.00
# Ep 895	 done after 18 iteractions	 epsilon=0.00
# Ep 896	 done after 12 iteractions	 epsilon=0.00
# Ep 897	 done after 12 iteractions	 epsilon=0.00
# Ep 898	 done after 14 iteractions	 epsilon=0.00
# Ep 899	 done after 6 iteractions	 epsilon=0.00
# Ep 900	 done after 10 iteractions	 epsilon=0.00
# Ep 901	 done after 14 iteractions	 epsilon=0.00
# Ep 902	 done after 8 iteractions	 epsilon=0.00
# Ep 903	 done after 15 iteractions	 epsilon=0.00
# Ep 904	 done after 12 iteractions	 epsilon=0.00
# Ep 905	 done after 13 iteractions	 epsilon=0.00
# Ep 906	 done after 10 iteractions	 epsilon=0.00
# Ep 907	 done after 12 iteractions	 epsilon=0.00
# Ep 908	 done after 13 iteractions	 epsilon=0.00
# Ep 909	 done after 14 iteractions	 epsilon=0.00
# Ep 910	 done after 10 iteractions	 epsilon=0.00
# Ep 911	 done after 18 iteractions	 epsilon=0.00
# Ep 912	 done after 10 iteractions	 epsilon=0.00
# Ep 913	 done after 12 iteractions	 epsilon=0.00
# Ep 914	 done after 17 iteractions	 epsilon=0.00
# Ep 915	 done after 10 iteractions	 epsilon=0.00
# Ep 916	 done after 15 iteractions	 epsilon=0.00
# Ep 917	 done after 12 iteractions	 epsilon=0.00
# Ep 918	 done after 14 iteractions	 epsilon=0.00
# Ep 919	 done after 18 iteractions	 epsilon=0.00
# Ep 920	 done after 15 iteractions	 epsilon=0.00
# Ep 921	 done after 15 iteractions	 epsilon=0.00
# Ep 922	 done after 14 iteractions	 epsilon=0.00
# Ep 923	 done after 14 iteractions	 epsilon=0.00
# Ep 924	 done after 10 iteractions	 epsilon=0.00
# Ep 925	 done after 15 iteractions	 epsilon=0.00
# Ep 926	 done after 11 iteractions	 epsilon=0.00
# Ep 927	 done after 14 iteractions	 epsilon=0.00
# Ep 928	 done after 11 iteractions	 epsilon=0.00
# Ep 929	 done after 8 iteractions	 epsilon=0.00
# Ep 930	 done after 12 iteractions	 epsilon=0.00
# Ep 931	 done after 14 iteractions	 epsilon=0.00
# Ep 932	 done after 17 iteractions	 epsilon=0.00
# Ep 933	 done after 14 iteractions	 epsilon=0.00
# Ep 934	 done after 16 iteractions	 epsilon=0.00
# Ep 935	 done after 17 iteractions	 epsilon=0.00
# Ep 936	 done after 12 iteractions	 epsilon=0.00
# Ep 937	 done after 15 iteractions	 epsilon=0.00
# Ep 938	 done after 15 iteractions	 epsilon=0.00
# Ep 939	 done after 14 iteractions	 epsilon=0.00
# Ep 940	 done after 7 iteractions	 epsilon=0.00
# Ep 941	 done after 14 iteractions	 epsilon=0.00
# Ep 942	 done after 13 iteractions	 epsilon=0.00
# Ep 943	 done after 14 iteractions	 epsilon=0.00
# Ep 944	 done after 14 iteractions	 epsilon=0.00
# Ep 945	 done after 10 iteractions	 epsilon=0.00
# Ep 946	 done after 13 iteractions	 epsilon=0.00
# Ep 947	 done after 12 iteractions	 epsilon=0.00
# Ep 948	 done after 16 iteractions	 epsilon=0.00
# Ep 949	 done after 13 iteractions	 epsilon=0.00
# Ep 950	 done after 13 iteractions	 epsilon=0.00
# Ep 951	 done after 10 iteractions	 epsilon=0.00
# Ep 952	 done after 13 iteractions	 epsilon=0.00
# Ep 953	 done after 16 iteractions	 epsilon=0.00
# Ep 954	 done after 12 iteractions	 epsilon=0.00
# Ep 955	 done after 13 iteractions	 epsilon=0.00
# Ep 956	 done after 13 iteractions	 epsilon=0.00
# Ep 957	 done after 16 iteractions	 epsilon=0.00
# Ep 958	 done after 17 iteractions	 epsilon=0.00
# Ep 959	 done after 13 iteractions	 epsilon=0.00
# Ep 960	 done after 11 iteractions	 epsilon=0.00
# Ep 961	 done after 13 iteractions	 epsilon=0.00
# Ep 962	 done after 10 iteractions	 epsilon=0.00
# Ep 963	 done after 9 iteractions	 epsilon=0.00
# Ep 964	 done after 18 iteractions	 epsilon=0.00
# Ep 965	 done after 13 iteractions	 epsilon=0.00
# Ep 966	 done after 9 iteractions	 epsilon=0.00
# Ep 967	 done after 14 iteractions	 epsilon=0.00
# Ep 968	 done after 9 iteractions	 epsilon=0.00
# Ep 969	 done after 16 iteractions	 epsilon=0.00
# Ep 970	 done after 11 iteractions	 epsilon=0.00
# Ep 971	 done after 13 iteractions	 epsilon=0.00
# Ep 972	 done after 13 iteractions	 epsilon=0.00
# Ep 973	 done after 14 iteractions	 epsilon=0.00
# Ep 974	 done after 13 iteractions	 epsilon=0.00
# Ep 975	 done after 17 iteractions	 epsilon=0.00
# Ep 976	 done after 7 iteractions	 epsilon=0.00
# Ep 977	 done after 7 iteractions	 epsilon=0.00
# Ep 978	 done after 13 iteractions	 epsilon=0.00
# Ep 979	 done after 15 iteractions	 epsilon=0.00
# Ep 980	 done after 11 iteractions	 epsilon=0.00
# Ep 981	 done after 15 iteractions	 epsilon=0.00
# Ep 982	 done after 15 iteractions	 epsilon=0.00
# Ep 983	 done after 11 iteractions	 epsilon=0.00
# Ep 984	 done after 17 iteractions	 epsilon=0.00
# Ep 985	 done after 10 iteractions	 epsilon=0.00
# Ep 986	 done after 13 iteractions	 epsilon=0.00
# Ep 987	 done after 13 iteractions	 epsilon=0.00
# Ep 988	 done after 9 iteractions	 epsilon=0.00
# Ep 989	 done after 13 iteractions	 epsilon=0.00
# Ep 990	 done after 12 iteractions	 epsilon=0.00
# Ep 991	 done after 12 iteractions	 epsilon=0.00
# Ep 992	 done after 17 iteractions	 epsilon=0.00
# Ep 993	 done after 15 iteractions	 epsilon=0.00
# Ep 994	 done after 14 iteractions	 epsilon=0.00
# Ep 995	 done after 14 iteractions	 epsilon=0.00
# Ep 996	 done after 12 iteractions	 epsilon=0.00
# Ep 997	 done after 11 iteractions	 epsilon=0.00
# Ep 998	 done after 11 iteractions	 epsilon=0.00
# Ep 999	 done after 13 iteractions	 epsilon=0.00
# Ep 1000	 done after 14 iteractions	 epsilon=0.00

# %%
# Plot rewards x episode

plt.plot(rewards)
plt.ylabel('Reward')
plt.xlabel('Episode')
plt.show()

# %%
def visualise_agent(policy, n_episodes=5):
    for ep in range(n_episodes):
        done = False
        n_iter = 0
        observation = env.reset()
        ep_reward = 0.0
        while not done:
            env.render()
            action = policy(observation)
            observation, reward, done, _ = env.step(action)
            time.sleep(0.5)
            ep_reward += reward
            n_iter += 1
        print("Ep {}, finished after {} timesteps, total reward={:.2f}".format(ep+1, n_iter, ep_reward))
        agent.epsilon *= 0.95
        print()
    env.close()

# %%
visualise_agent(agent.get_best_action, n_episodes=2)
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : |_: |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : :_: |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : :_: : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : | : : |
# | :_: : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : | : : |
# |_: : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# |_| : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Ep 1, finished after 16 timesteps, total reward=5.00
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# +---------+
# |R: | :_:G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : | :_: |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : :_: |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : :_: : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : | : : |
# | :_: : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : | : : |
# |_: : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# |_| : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Ep 2, finished after 12 timesteps, total reward=9.00
